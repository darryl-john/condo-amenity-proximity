# %%
import pandas as pd
import requests

# %%
df = pd.read_csv('data_others/train-stations.csv')
df.describe()
# Out:
#          line      station                           location  \
# count      56           56                                 56
# unique      4           54                                 55
# top     LRT-1  Blumentritt  EDSA, South Triangle, Quezon City
# freq       25            2                                  2
#
#                                          full_address
# count                                              56
# unique                                             56
# top     MRT-3 North Avenue Station, EDSA, Quezon City
# freq                                                1

# %%
API_KEY = "AIzaSyATTWZx0JUPqeaHjm718D0SZsrA5T16kOI"

# Function to get coordinates from Google Maps Geocoding API
def get_coordinates(location):
    url = "https://maps.googleapis.com/maps/api/geocode/json"
    params = {"address": location, "key": API_KEY}
    r = requests.get(url, params=params)
    results = r.json().get("results")
    if results:
        location = results[0]["geometry"]["location"]
        return location["lat"], location["lng"]
    return None, None

# Get coordinates for each hospital
df[["latitude", "longitude"]] = df["full_address"].apply(lambda x: pd.Series(get_coordinates(x)))
df
# Out:
#      line               station  \
# 0   MRT-3          North Avenue
# 1   MRT-3         Quezon Avenue
# 2   MRT-3          GMA–Kamuning
# 3   MRT-3  Araneta Center–Cubao
# 4   MRT-3    Santolan–Annapolis
# 5   MRT-3               Ortigas
# 6   MRT-3        Shaw Boulevard
# 7   MRT-3             Guadalupe
# 8   MRT-3   Buendia (Gil Puyat)
# 9   MRT-3                 Ayala
# 10  MRT-3            Magallanes
# 11  MRT-3           Taft Avenue
# 12  LRT-1      Fernando Poe Jr.
# 13  LRT-1            Balintawak
# 14  LRT-1             Monumento
# 15  LRT-1            5th Avenue
# 16  LRT-1               R. Papa
# 17  LRT-1           Abad Santos
# 18  LRT-1           Blumentritt
# 19  LRT-1               Tayuman
# 20  LRT-1               Bambang
# 21  LRT-1          Doroteo Jose
# 22  LRT-1              Carriedo
# 23  LRT-1      Central Terminal
# 24  LRT-1             UN Avenue
# 25  LRT-1             Pedro Gil
# 26  LRT-1        Quirino Avenue
# 27  LRT-1             Vito Cruz
# 28  LRT-1             Gil Puyat
# 29  LRT-1              Libertad
# 30  LRT-1                  EDSA
# 31  LRT-1              Baclaran
# 32  LRT-1   Redemptorist–Aseana
# 33  LRT-1              MIA Road
# 34  LRT-1                  PITX
# 35  LRT-1   Ninoy Aquino Avenue
# 36  LRT-1            Dr. Santos
# 37  LRT-2                 Recto
# 38  LRT-2               Legarda
# 39  LRT-2                Pureza
# 40  LRT-2               V. Mapa
# 41  LRT-2               J. Ruiz
# 42  LRT-2               Gilmore
# 43  LRT-2     Betty Go–Belmonte
# 44  LRT-2                 Cubao
# 45  LRT-2                Anonas
# 46  LRT-2             Katipunan
# 47  LRT-2              Santolan
# 48  LRT-2              Marikina
# 49  LRT-2              Antipolo
# 50    PNR               Tutuban
# 51    PNR           Blumentritt
# 52    PNR              Pandacan
# 53    PNR                  Paco
# 54    PNR            San Andres
# 55    PNR             Vito Cruz
#
#                                              location  \
# 0                                   EDSA, Quezon City
# 1                   EDSA, South Triangle, Quezon City
# 2                   EDSA, South Triangle, Quezon City
# 3                            EDSA, Cubao, Quezon City
# 4                   EDSA, Camp Aguinaldo, Quezon City
# 5        EDSA, Wack-Wack Greenhills, Mandaluyong City
# 6               EDSA, Highway Hills, Mandaluyong City
# 7                  EDSA, Guadalupe Nuevo, Makati City
# 8                         EDSA, Urdaneta, Makati City
# 9                           Ayala Avenue, Makati City
# 10                      EDSA, Magallanes, Makati City
# 11                EDSA corner Taft Avenue, Pasay City
# 12               EDSA, Veteran's Village, Quezon City
# 13                      EDSA, Balintawak, Quezon City
# 14                           Monumento, Caloocan City
# 15                          5th Avenue, Caloocan City
# 16                      R. Papa Street, Caloocan City
# 17                                Abad Santos, Manila
# 18                         Blumentritt Street, Manila
# 19                                    Tayuman, Manila
# 20                                    Bambang, Manila
# 21                           Doroteo Jose St., Manila
# 22                                   Carriedo, Manila
# 23          Mayor Antonio Villegas Rd, Ermita, Manila
# 24                                  UN Avenue, Manila
# 25                                  Pedro Gil, Manila
# 26                               Quirino Blvd, Manila
# 27                        Taft Avenue, Malate, Manila
# 28                            Gil Puyat Avenue, Pasay
# 29                    Taft Avenue, Santa Clara, Pasay
# 30                     Taft Avenue, San Rafael, Pasay
# 31            Taft Avenue Extension, Sto. Niño, Pasay
# 32                   Aseana City, Baclaran, Parañaque
# 33                           MIA Road, Parañaque City
# 34            PITX, Kennedy Road, Don Galo, Parañaque
# 35         Ninoy Aquino Avenue, Santo Niño, Parañaque
# 36                       San Dionisio, Parañaque City
# 37                               Recto Avenue, Manila
# 38                   Legarda Street, Sampaloc, Manila
# 39                  Pureza Street, Santa Mesa, Manila
# 40                        Magsaysay Boulevard, Manila
# 41                                      San Juan City
# 42                        Gilmore Avenue, Quezon City
# 43                          Mariana area, Quezon City
# 44                                 Cubao, Quezon City
# 45                      Aurora Boulevard, Quezon City
# 46      Katipunan Avenue, Loyola Heights, Quezon City
# 47                 Marikina–Infanta Highway, Marikina
# 48                                      Marikina City
# 49                                    Antipolo, Rizal
# 50                   Mayhaligue Street, Tondo, Manila
# 51            Old Antipolo Street, Santa Cruz, Manila
# 52  Tomas Claudio (Padre Zamora) Street, Pandacan,...
# 53      Quirino Avenue near Plaza Dilao, Paco, Manila
# 54              San Andres St, Osmeña Highway, Manila
# 55     Osmeña Highway corner Pablo Ocampo St., Manila
#
#                                          full_address   latitude   longitude
# 0       MRT-3 North Avenue Station, EDSA, Quezon City  14.652170  121.032333
# 1   MRT-3 Quezon Avenue Station, EDSA, South Trian...  14.642760  121.038508
# 2   MRT-3 GMA–Kamuning Station, EDSA, South Triang...  14.635217  121.043343
# 3   MRT-3 Araneta Center–Cubao Station, EDSA, Cuba...  14.619488  121.051131
# 4   MRT-3 Santolan–Annapolis Station, EDSA, Camp A...  14.607817  121.056414
# 5   MRT-3 Ortigas Station, EDSA, Wack-Wack Greenhi...  14.587849  121.056723
# 6   MRT-3 Shaw Boulevard Station, EDSA, Highway Hi...  14.581206  121.053597
# 7   MRT-3 Guadalupe Station, EDSA, Guadalupe Nuevo...  14.567599  121.045766
# 8   MRT-3 Buendia (Gil Puyat) Station, EDSA, Urdan...  14.551930  121.031199
# 9      MRT-3 Ayala Station, Ayala Avenue, Makati City  14.549191  121.027970
# 10  MRT-3 Magallanes Station, EDSA, Magallanes, Ma...  14.542023  121.019485
# 11  MRT-3 Taft Avenue Station, EDSA corner Taft Av...  14.537669  121.002175
# 12  LRT-1 Fernando Poe Jr. Station, EDSA, Veteran'...  14.657605  121.021101
# 13  LRT-1 Balintawak Station, EDSA, Balintawak, Qu...  14.657383  121.003729
# 14  LRT-1 Monumento Station, Monumento, Caloocan City  14.654367  120.983894
# 15  LRT-1 5th Avenue Station, 5th Avenue, Caloocan...  14.644490  120.976310
# 16  LRT-1 R. Papa Station, R. Papa Street, Calooca...  14.636153  120.982342
# 17     LRT-1 Abad Santos Station, Abad Santos, Manila  14.630586  120.981422
# 18  LRT-1 Blumentritt Station, Blumentritt Street,...  14.622746  120.983535
# 19             LRT-1 Tayuman Station, Tayuman, Manila  14.616756  120.982736
# 20             LRT-1 Bambang Station, Bambang, Manila  14.611090  120.981178
# 21  LRT-1 Doroteo Jose Station, Doroteo Jose St., ...  14.605348  120.981973
# 22           LRT-1 Carriedo Station, Carriedo, Manila  14.599120  120.981352
# 23  LRT-1 Central Terminal Station, Mayor Antonio ...  14.592752  120.981633
# 24         LRT-1 UN Avenue Station, UN Avenue, Manila  14.582550  120.984621
# 25         LRT-1 Pedro Gil Station, Pedro Gil, Manila  14.576321  120.988188
# 26  LRT-1 Quirino Avenue Station, Quirino Blvd, Ma...  14.570300  120.991560
# 27  LRT-1 Vito Cruz Station, Taft Avenue, Malate, ...  14.563344  120.994851
# 28   LRT-1 Gil Puyat Station, Gil Puyat Avenue, Pasay  14.554294  120.997107
# 29  LRT-1 Libertad Station, Taft Avenue, Santa Cla...  14.550288  120.998125
# 30  LRT-1 EDSA Station, Taft Avenue, San Rafael, P...  14.550288  120.998125
# 31  LRT-1 Baclaran Station, Taft Avenue Extension,...  14.534231  120.998350
# 32  LRT-1 Redemptorist–Aseana Station, Aseana City...  14.526992  120.982619
# 33   LRT-1 MIA Road Station, MIA Road, Parañaque City  14.518510  120.993000
# 34  LRT-1 PITX Station, PITX, Kennedy Road, Don Ga...  14.510099  120.990896
# 35  LRT-1 Ninoy Aquino Avenue Station, Ninoy Aquin...  14.499009  120.994282
# 36  LRT-1 Dr. Santos Station, San Dionisio, Paraña...  14.485248  120.989420
# 37          LRT-2 Recto Station, Recto Avenue, Manila  14.603515  120.983074
# 38  LRT-2 Legarda Station, Legarda Street, Sampalo...  14.600866  120.992576
# 39  LRT-2 Pureza Station, Pureza Street, Santa Mes...  14.601746  121.005178
# 40  LRT-2 V. Mapa Station, Magsaysay Boulevard, Ma...  14.604080  121.017140
# 41               LRT-2 J. Ruiz Station, San Juan City  14.610554  121.026208
# 42  LRT-2 Gilmore Station, Gilmore Avenue, Quezon ...  14.613531  121.034176
# 43  LRT-2 Betty Go–Belmonte Station, Mariana area,...  14.618521  121.042706
# 44            LRT-2 Cubao Station, Cubao, Quezon City  14.622686  121.052612
# 45  LRT-2 Anonas Station, Aurora Boulevard, Quezon...  14.628014  121.064752
# 46  LRT-2 Katipunan Station, Katipunan Avenue, Loy...  14.630772  121.072701
# 47  LRT-2 Santolan Station, Marikina–Infanta Highw...  14.622116  121.085940
# 48              LRT-2 Marikina Station, Marikina City  14.634930  121.101954
# 49            LRT-2 Antipolo Station, Antipolo, Rizal  14.623479  121.119167
# 50  PNR Tutuban Station, Mayhaligue Street, Tondo,...  14.611366  120.973078
# 51  PNR Blumentritt Station, Old Antipolo Street, ...  14.622605  120.983618
# 52  PNR Pandacan Station, Tomas Claudio (Padre Zam...  14.590240  121.008800
# 53  PNR Paco Station, Quirino Avenue near Plaza Di...  14.579258  120.999442
# 54  PNR San Andres Station, San Andres St, Osmeña ...  14.573246  120.999447
# 55  PNR Vito Cruz Station, Osmeña Highway corner P...  14.567205  121.002840

# %%
# Save the DataFrame to a CSV file
df.to_csv("geocoded-train-stations.csv", index=False, encoding='utf-8-sig')
