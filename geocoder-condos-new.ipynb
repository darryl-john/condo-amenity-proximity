# %%
import os, glob, json, requests
import pandas as pd

# %%
records = []

# Append data from all text files in the data_condo_listings directory
for filepath in  glob.glob(os.path.join("data_condos_new", "*.txt")):
    with open(filepath, 'r', encoding='utf-8') as f:
        for line in f:
            records.append(json.loads(line))

df = pd.DataFrame(records)
df.describe()
# Out:
#                                                     title  \
# count                                                 550
# unique                                                487
# top     Pre-Selling 2-Bedroom Condo for Sale in Edades...
# freq                                                    8
#
#                   project_unit            project_name    area floor_area  \
# count                      298                     298     321        550
# unique                      93                      93     131        184
# top     Proscenium at Rockwell  Proscenium at Rockwell  37 sqm     37 sqm
# freq                        15                      15      11         14
#
#                price              location   bedrooms   bathrooms floor  \
# count            513                   550        497         503   240
# unique           220                    15          6           5    59
# top     ₱ 35,000,000  Makati, Metro Manila  1 bedroom  1 bathroom    30
# freq              13                   159        201         242    15
#
#               condition property_type offer_type construction_year  \
# count               446           550        550                79
# unique                3             5          2                22
# top     Fully furnished         Condo   For Sale              2025
# freq                249           488        507                10
#
#        parking_spaces ownership_type  \
# count             317            157
# unique              5              2
# top                 1       Freehold
# freq              192            125
#
#                                              project_link  \
# count                                                 298
# unique                                                 93
# top     https://www.lamudi.com.ph/projects/proscenium-...
# freq                                                   15
#
#                publish_date               publish_by
# count                   550                      550
# unique                  105                      124
# top     2 weeks, 5 days ago  HousingInteractive Inc.
# freq                     35                       42

# %%
# Drop 'publish_date' column and remove duplicates
df = df.drop(columns=['publish_date']).drop_duplicates()
df.describe()
# Out:
#                                                     title  \
# count                                                 536
# unique                                                487
# top     Pre-Selling 2-Bedroom Condo for Sale in Edades...
# freq                                                    7
#
#                   project_unit            project_name    area floor_area  \
# count                      292                     292     311        536
# unique                      93                      93     131        184
# top     Proscenium at Rockwell  Proscenium at Rockwell  36 sqm    106 sqm
# freq                        14                      14       9         12
#
#                price              location   bedrooms   bathrooms floor  \
# count            500                   536        484         490   232
# unique           220                    15          6           5    59
# top     ₱ 35,000,000  Makati, Metro Manila  1 bedroom  1 bathroom    30
# freq              13                   153        191         231    14
#
#               condition property_type offer_type construction_year  \
# count               437           536        536                74
# unique                3             5          2                22
# top     Fully furnished         Condo   For Sale              2025
# freq                246           474        497                 9
#
#        parking_spaces ownership_type  \
# count             311            151
# unique              5              2
# top                 1       Freehold
# freq              186            119
#
#                                              project_link  \
# count                                                 292
# unique                                                 93
# top     https://www.lamudi.com.ph/projects/proscenium-...
# freq                                                   14
#
#                      publish_by
# count                       536
# unique                      124
# top     HousingInteractive Inc.
# freq                         42

# %%
#
