# %%
import pandas as pd
import os, glob, json

# %%
records = []

# Append data from all text files in the data_listings directory
for filepath in  glob.glob(os.path.join("data_listings/text_files", "*.txt")):
    with open(filepath, 'r', encoding='utf-8') as f:
        for line in f:
            records.append(json.loads(line))

df = pd.DataFrame(records)
df.describe(include='all')
# Out:
#              city         page  \
# count        7981  7981.000000
# unique         11          NaN
# top     paranaque          NaN
# freq         1500          NaN
# mean          NaN    22.534895
# std           NaN    14.668806
# min           NaN     1.000000
# 25%           NaN     9.000000
# 50%           NaN    22.000000
# 75%           NaN    35.000000
# max           NaN    50.000000
#
#                                                     title  \
# count                                               15601
# unique                                              10716
# top     Quantum Residences Ready For Occupancy near LR...
# freq                                                  109
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# ...

# %%
df = df.drop(columns=['city', 'page'])
df
# Out:
#                                                    title  \
# 0      3BR Condo Calinea Near SM Grand Central Monume...
# 1      2BR CondoNear SM grand Central Calinea DMCI Pr...
# 2      Calinea tower 126sqm 3BR DMCI newest Presellin...
# 3        Spacious Studio Condo For Sale in Caloocan City
# 4                            FOR SALE: The Calinea Tower
# ...                                                  ...
# 15596  VICTORIA DE VALENZUELA Near Our Lady of Fatima...
# 15597  CONDO NEAR FATIMA UNIVERSITY AND MCU MEDICAL C...
# 15598  affordable condominium in valenzuela city near...
# 15599  condominium in valenzuela near fatima universi...
# 15600  BANK FORECLOSED PROPERTY ON SALE!! HURRY! AVAI...
#
#                                              description       project_unit  \
# 0      Enjoy excellent accessibility by living in THE...  The Calinea Tower
# 1      THE CALINEA TOWER by DMCI Homes\n\nM. H. Del P...  The Calinea Tower
# ...

# %%
# Save the DataFrame to a CSV file
df.to_csv("data-listings.csv", index=False, encoding='utf-8-sig')
