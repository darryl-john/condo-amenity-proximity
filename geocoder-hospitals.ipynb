# %%
import pandas as pd
import requests

# %%
df = pd.read_csv('data_others/philhealth-ncr-hospitals.csv')
df['full_address'] = df['hospital'] + ', ' + df['street'] + ', ' + df['city'] + ', METRO MANILA, PHILIPPINES'
df
# Out:
#                                               hospital  beds  category  \
# 0    ALLIED CARE EXPERTS (ACE) MEDICAL\nCENTER - QU...   100   LEVEL 2
# 1              AMANG RODRIGUEZ MEMORIAL MEDICAL CENTER   300   LEVEL 3
# 2                        BERNARDINO GENERAL HOSPITAL I    80   LEVEL 2
# 3                       BERNARDINO GENERAL HOSPITAL II    35   LEVEL 1
# 4    CABARLES MATERNITY (LYING-IN), MEDICAL AND CHI...     9  INF/DISP
# ..                                                 ...   ...       ...
# 164                         THE PREMIER MEDICAL CENTER    40   LEVEL 2
# 165                       TRICITY MEDICAL CENTER, INC.   100   LEVEL 2
# 166              UHBI-PARAÑAQUE DOCTORS HOSPITAL, INC.    94   LEVEL 2
# 167  UNIHEALTH PARAÑAQUE HOSPITAL AND\nMEDICAL CENT...   100   LEVEL 2
# 168  UNIVERSITY OF PERPETUAL HELP DALTA MEDICAL CEN...   285   LEVEL 3
#
#                                                 street            city sec  \
# 0         NO. 20 SEMINARY ROAD, BAHAY TORO,\nPROJECT 8     QUEZON CITY   P
# 1                     SUMULONG HIWAY, BRGY. STO. NIÑO,   MARIKINA CITY   G
# 2     680 QUIRINO HIGHWAY, SAN\nBARTOLOME, NOVALICHES,     QUEZON CITY   P
# 3    B1 L2 NORTH OLYMPUS SUBD., ZABARTE ROAD, BRGY....     QUEZON CITY   P
# 4    2 HEAVENLY DRIVE, CORNER SUSANO ROAD, SAN AGUS...     QUEZON CITY   P
# ..                                                 ...             ...  ..
# 164  LOT 2 AMVEL BUSINESS PARK, DR. A. SANTOS AVE.,...  PARAÑAQUE CITY   P
# 165                 269 C. RAYMUNDO AVENUE,\nMAYBUNGA,      PASIG CITY   P
# 166        175 DOÑA SOLEDAD AVE.,\nBETTERLIVING SUBD.,  PARAÑAQUE CITY   P
# 167  DR. A SANTOS AVENUE, BRGY. SAN\nISIDRO, SUCAT ...  PARAÑAQUE CITY   P
# 168                 ALABANG ZAPOTE ROAD, PAMPLONA TRES  LAS PIÑAS CITY   P
#
#                                           full_address
# 0    ALLIED CARE EXPERTS (ACE) MEDICAL\nCENTER - QU...
# 1    AMANG RODRIGUEZ MEMORIAL MEDICAL CENTER, SUMUL...
# 2    BERNARDINO GENERAL HOSPITAL I, 680 QUIRINO HIG...
# 3    BERNARDINO GENERAL HOSPITAL II, B1 L2 NORTH OL...
# 4    CABARLES MATERNITY (LYING-IN), MEDICAL AND CHI...
# ..                                                 ...
# 164  THE PREMIER MEDICAL CENTER, LOT 2 AMVEL BUSINE...
# 165  TRICITY MEDICAL CENTER, INC., 269 C. RAYMUNDO ...
# 166  UHBI-PARAÑAQUE DOCTORS HOSPITAL, INC., 175 DOÑ...
# 167  UNIHEALTH PARAÑAQUE HOSPITAL AND\nMEDICAL CENT...
# 168  UNIVERSITY OF PERPETUAL HELP DALTA MEDICAL CEN...
#
# [169 rows x 7 columns]

# %%
API_KEY = "AIzaSyATTWZx0JUPqeaHjm718D0SZsrA5T16kOI"

# Function to get coordinates from Google Maps Geocoding API
def get_coordinates(location):
    url = "https://maps.googleapis.com/maps/api/geocode/json"
    params = {"address": location, "key": API_KEY}
    r = requests.get(url, params=params)
    results = r.json().get("results")
    if results:
        location = results[0]["geometry"]["location"]
        return location["lat"], location["lng"]
    return None, None

# Get coordinates for each hospital
df[["latitude", "longitude"]] = df["full_address"].apply(lambda x: pd.Series(get_coordinates(x)))
df
# Out:
#                                               hospital  beds  category  \
# 0    ALLIED CARE EXPERTS (ACE) MEDICAL\nCENTER - QU...   100   LEVEL 2
# 1              AMANG RODRIGUEZ MEMORIAL MEDICAL CENTER   300   LEVEL 3
# 2                        BERNARDINO GENERAL HOSPITAL I    80   LEVEL 2
# 3                       BERNARDINO GENERAL HOSPITAL II    35   LEVEL 1
# 4    CABARLES MATERNITY (LYING-IN), MEDICAL AND CHI...     9  INF/DISP
# ..                                                 ...   ...       ...
# 164                         THE PREMIER MEDICAL CENTER    40   LEVEL 2
# 165                       TRICITY MEDICAL CENTER, INC.   100   LEVEL 2
# 166              UHBI-PARAÑAQUE DOCTORS HOSPITAL, INC.    94   LEVEL 2
# 167  UNIHEALTH PARAÑAQUE HOSPITAL AND\nMEDICAL CENT...   100   LEVEL 2
# 168  UNIVERSITY OF PERPETUAL HELP DALTA MEDICAL CEN...   285   LEVEL 3
#
#                                                 street            city sec  \
# 0         NO. 20 SEMINARY ROAD, BAHAY TORO,\nPROJECT 8     QUEZON CITY   P
# 1                     SUMULONG HIWAY, BRGY. STO. NIÑO,   MARIKINA CITY   G
# 2     680 QUIRINO HIGHWAY, SAN\nBARTOLOME, NOVALICHES,     QUEZON CITY   P
# 3    B1 L2 NORTH OLYMPUS SUBD., ZABARTE ROAD, BRGY....     QUEZON CITY   P
# 4    2 HEAVENLY DRIVE, CORNER SUSANO ROAD, SAN AGUS...     QUEZON CITY   P
# ..                                                 ...             ...  ..
# 164  LOT 2 AMVEL BUSINESS PARK, DR. A. SANTOS AVE.,...  PARAÑAQUE CITY   P
# 165                 269 C. RAYMUNDO AVENUE,\nMAYBUNGA,      PASIG CITY   P
# 166        175 DOÑA SOLEDAD AVE.,\nBETTERLIVING SUBD.,  PARAÑAQUE CITY   P
# 167  DR. A SANTOS AVENUE, BRGY. SAN\nISIDRO, SUCAT ...  PARAÑAQUE CITY   P
# 168                 ALABANG ZAPOTE ROAD, PAMPLONA TRES  LAS PIÑAS CITY   P
#
#                                           full_address   latitude   longitude
# 0    ALLIED CARE EXPERTS (ACE) MEDICAL\nCENTER - QU...  14.660416  121.017192
# 1    AMANG RODRIGUEZ MEMORIAL MEDICAL CENTER, SUMUL...  14.635884  121.098234
# 2    BERNARDINO GENERAL HOSPITAL I, 680 QUIRINO HIG...  14.700306  121.034954
# 3    BERNARDINO GENERAL HOSPITAL II, B1 L2 NORTH OL...  14.738164  121.047060
# 4    CABARLES MATERNITY (LYING-IN), MEDICAL AND CHI...  14.728867  121.036997
# ..                                                 ...        ...         ...
# 164  THE PREMIER MEDICAL CENTER, LOT 2 AMVEL BUSINE...  14.488678  120.993098
# 165  TRICITY MEDICAL CENTER, INC., 269 C. RAYMUNDO ...  14.575910  121.085191
# 166  UHBI-PARAÑAQUE DOCTORS HOSPITAL, INC., 175 DOÑ...  14.485867  121.028415
# 167  UNIHEALTH PARAÑAQUE HOSPITAL AND\nMEDICAL CENT...  14.464536  121.019618
# 168  UNIVERSITY OF PERPETUAL HELP DALTA MEDICAL CEN...  14.448091  120.985884
#
# [169 rows x 9 columns]

# %%
# Save the DataFrame to a CSV file
df.to_csv("geocoded-hospitals.csv", index=False, encoding='utf-8-sig')
